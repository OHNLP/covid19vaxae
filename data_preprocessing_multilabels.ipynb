# %% [markdown]
# # Preprocess the VAERS data for multi-labels

# %%
import os
import pandas as pd
from tqdm import tqdm
import itertools

# %% [markdown]
# # Load raw data

# %%
# load data 2020
df_vax_20 = pd.read_csv('raw/2020VAERSVAX.csv.zip', encoding='cp1252')
df_sym_20 = pd.read_csv('raw/2020VAERSSYMPTOMS.csv.zip', encoding='cp1252')
df_rpt_20 = pd.read_csv('raw/2020VAERSDATA.csv.zip', encoding='cp1252')
print('* df 20 report size:', df_rpt_20.VAERS_ID.count())
print('* df 20 symptom size:', df_sym_20.VAERS_ID.count())
print('* df 20 vax size:', df_vax_20.VAERS_ID.count())

# load data 2021
df_vax_21 = pd.read_csv('raw/2021VAERSVAX.csv.zip', encoding='cp1252')
df_sym_21 = pd.read_csv('raw/2021VAERSSYMPTOMS.csv.zip', encoding='cp1252')
df_rpt_21 = pd.read_csv('raw/2021VAERSDATA.csv.zip', encoding='cp1252')
print('* df 21 report size:', df_rpt_21.VAERS_ID.count())
print('* df 21 symptom size:', df_sym_21.VAERS_ID.count())
print('* df 21 vax size:', df_vax_21.VAERS_ID.count())
# Out:
# * df 20 report size: 46933
# * df 20 symptom size: 57716
# * df 20 vax size: 56372
# * df 21 report size: 146622
# * df 21 symptom size: 200255
# * df 21 vax size: 149251
# /home/hehuan/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (7,12,23) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ## Merge 2020 and 2021 data

# %%
df_vax = pd.concat([df_vax_20, df_vax_21])
df_sym = pd.concat([df_sym_20, df_sym_21])
df_rpt = pd.concat([df_rpt_20, df_rpt_21])

print('* df report size:', df_rpt.VAERS_ID.count())
print('* df symptom size:', df_sym.VAERS_ID.count())
print('* df vax size:', df_vax.VAERS_ID.count())
# Out:
# * df report size: 193555
# * df symptom size: 257971
# * df vax size: 205623

# %% [markdown]
# ## Check the data

# %%
df_vax.head()
# Out:
#    VAERS_ID VAX_TYPE                     VAX_MANU VAX_LOT VAX_DOSE_SERIES  \
# 0    855017   VARZOS  GLAXOSMITHKLINE BIOLOGICALS     NaN               2
# 1    855018      UNK         UNKNOWN MANUFACTURER     NaN               1
# 2    855019   VARZOS  GLAXOSMITHKLINE BIOLOGICALS     NaN             UNK
# 3    855020   VARZOS  GLAXOSMITHKLINE BIOLOGICALS     NaN             UNK
# 4    855021   VARZOS  GLAXOSMITHKLINE BIOLOGICALS     NaN               2
#
#   VAX_ROUTE VAX_SITE                       VAX_NAME
# 0       SYR       LA              ZOSTER (SHINGRIX)
# 1        IM       RA  VACCINE NOT SPECIFIED (OTHER)
# 2       NaN      NaN              ZOSTER (SHINGRIX)
# 3        IM       LA              ZOSTER (SHINGRIX)
# 4        IM       RA              ZOSTER (SHINGRIX)

# %%
df_sym.head()
# Out:
#    VAERS_ID           SYMPTOM1  SYMPTOMVERSION1                SYMPTOM2  \
# 0    855017         Arthralgia             22.1                  Chills
# 1    855018             Chills             22.1                 Fatigue
# 2    855018  Muscular weakness             22.1       Pain in extremity
# 3    855019               Pain             22.1                Pruritus
# 4    855020             Chills             22.1  Influenza like illness
#
#    SYMPTOMVERSION2             SYMPTOM3  SYMPTOMVERSION3           SYMPTOM4  \
# 0             22.1  Injection site pain             22.1            Pyrexia
# 1             22.1         Hypertension             22.1      Hypoaesthesia
# 2             22.1              Pyrexia             22.1             Tremor
# 3             22.1                 Rash             22.1                NaN
# 4             22.1              Myalgia             22.1  Pain in extremity
#
#    SYMPTOMVERSION4                          SYMPTOM5  SYMPTOMVERSION5
# 0             22.1                               NaN              NaN
# 1             22.1  Injected limb mobility decreased             22.1
# 2             22.1                           Vertigo             22.1
# 3              NaN                               NaN              NaN
# 4             22.1                           Pyrexia             22.1

# %%
df_rpt.head(6).T
# Out:
#                                                               0  \
# VAERS_ID                                                 855017
# RECVDATE                                             01/01/2020
# STATE                                                        HI
# AGE_YRS                                                      55
# CAGE_YR                                                      55
# CAGE_MO                                                     NaN
# SEX                                                           F
# RPT_DATE                                                    NaN
# SYMPTOM_TEXT  Symptoms occurred almost immediately- aching j...
# DIED                                                        NaN
# DATEDIED                                                    NaN
# L_THREAT                                                    NaN
# ER_VISIT                                                    NaN
# HOSPITAL                                                    NaN
# HOSPDAYS                                                    NaN
# X_STAY                                                      NaN
# DISABLE                                                     NaN
# RECOVD                                                        N
# VAX_DATE                                             12/30/2019
# ONSET_DATE                                           12/30/2019
# NUMDAYS                                                       0
# LAB_DATA                                                   None
# V_ADMINBY                                                   MIL
# V_FUNDBY                                                    NaN
# OTHER_MEDS                                             Loristan
# CUR_ILL                                                    None
# HISTORY                                               Migraines
# PRIOR_VAX                                                   NaN
# SPLTTYPE                                                    NaN
# FORM_VERS                                                     2
# TODAYS_DATE                                          01/01/2020
# BIRTH_DEFECT                                                NaN
# OFC_VISIT                                                   NaN
# ER_ED_VISIT                                                 NaN
# ALLERGIES                                              Morphine
#
#                                                               1  \
# VAERS_ID                                                 855018
# RECVDATE                                             01/01/2020
# STATE                                                        WI
# AGE_YRS                                                      68
# CAGE_YR                                                      68
# CAGE_MO                                                     NaN
# SEX                                                           F
# RPT_DATE                                                    NaN
# SYMPTOM_TEXT  Extreme pain, muscle weakness in right arm so ...
# DIED                                                        NaN
# DATEDIED                                                    NaN
# L_THREAT                                                    NaN
# ER_VISIT                                                    NaN
# HOSPITAL                                                    NaN
# HOSPDAYS                                                    NaN
# X_STAY                                                      NaN
# DISABLE                                                     NaN
# RECOVD                                                        Y
# VAX_DATE                                             12/30/2019
# ONSET_DATE                                           12/30/2019
# NUMDAYS                                                       0
# LAB_DATA      Same day 12/30/2019. No tests other than routi...
# V_ADMINBY                                                   PHM
# V_FUNDBY                                                    NaN
# OTHER_MEDS               levothyroxine, multi vitamin, calcium.
# CUR_ILL                                                    None
# HISTORY                      Hypothyroidism, Meniere's Disease.
# PRIOR_VAX                                                   NaN
# SPLTTYPE                                                    NaN
# FORM_VERS                                                     2
# TODAYS_DATE                                          01/01/2020
# BIRTH_DEFECT                                                NaN
# OFC_VISIT                                                     Y
# ER_ED_VISIT                                                   Y
# ALLERGIES     Penicillin, sulfa drugs, erythromycin, tetracy...
#
#                                                     2  \
# VAERS_ID                                       855019
# RECVDATE                                   01/01/2020
# STATE                                             NaN
# AGE_YRS                                            50
# CAGE_YR                                            50
# CAGE_MO                                           NaN
# SEX                                                 F
# RPT_DATE                                          NaN
# SYMPTOM_TEXT  SORENESS IN THE AREA.  ITCHING AND RASH
# DIED                                              NaN
# DATEDIED                                          NaN
# L_THREAT                                          NaN
# ER_VISIT                                          NaN
# HOSPITAL                                          NaN
# HOSPDAYS                                          NaN
# X_STAY                                            NaN
# DISABLE                                           NaN
# RECOVD                                            NaN
# VAX_DATE                                   12/23/2019
# ONSET_DATE                                 12/29/2019
# NUMDAYS                                             6
# LAB_DATA                                          NaN
# V_ADMINBY                                         UNK
# V_FUNDBY                                          NaN
# OTHER_MEDS                                        NaN
# CUR_ILL                                           NaN
# HISTORY                                           NaN
# PRIOR_VAX                                         NaN
# SPLTTYPE                                          NaN
# FORM_VERS                                           2
# TODAYS_DATE                                01/01/2020
# BIRTH_DEFECT                                      NaN
# OFC_VISIT                                         NaN
# ER_ED_VISIT                                       NaN
# ALLERGIES                                         NaN
#
#                                                               3  \
# VAERS_ID                                                 855020
# RECVDATE                                             01/01/2020
# STATE                                                        TX
# AGE_YRS                                                      67
# CAGE_YR                                                      67
# CAGE_MO                                                     NaN
# SEX                                                           F
# RPT_DATE                                                    NaN
# SYMPTOM_TEXT  sore arm,  fever 101 , chills, and aching musc...
# DIED                                                        NaN
# DATEDIED                                                    NaN
# L_THREAT                                                    NaN
# ER_VISIT                                                    NaN
# HOSPITAL                                                    NaN
# HOSPDAYS                                                    NaN
# X_STAY                                                      NaN
# DISABLE                                                     NaN
# RECOVD                                                        N
# VAX_DATE                                             12/01/2019
# ONSET_DATE                                           01/01/2020
# NUMDAYS                                                      31
# LAB_DATA                                                   none
# V_ADMINBY                                                   PHM
# V_FUNDBY                                                    NaN
# OTHER_MEDS               multi vitamin, calcium, premarin cream
# CUR_ILL                                                    none
# HISTORY                                                    none
# PRIOR_VAX                                                   NaN
# SPLTTYPE                                                    NaN
# FORM_VERS                                                     2
# TODAYS_DATE                                          01/01/2020
# BIRTH_DEFECT                                                NaN
# OFC_VISIT                                                   NaN
# ER_ED_VISIT                                                 NaN
# ALLERGIES                                             morphine,
#
#                                                               4  \
# VAERS_ID                                                 855021
# RECVDATE                                             01/01/2020
# STATE                                                       NaN
# AGE_YRS                                                      73
# CAGE_YR                                                      73
# CAGE_MO                                                     NaN
# SEX                                                           F
# RPT_DATE                                                    NaN
# SYMPTOM_TEXT  Patient presented to Clinic today 1/1/2020. Sh...
# DIED                                                        NaN
# DATEDIED                                                    NaN
# L_THREAT                                                    NaN
# ER_VISIT                                                    NaN
# HOSPITAL                                                    NaN
# HOSPDAYS                                                    NaN
# X_STAY                                                      NaN
# DISABLE                                                     NaN
# RECOVD                                                        U
# VAX_DATE                                             12/31/2019
# ONSET_DATE                                           12/31/2019
# NUMDAYS                                                       0
# LAB_DATA      Temp 99.7 here in clinic. Vital signs WNL othe...
# V_ADMINBY                                                   PHM
# V_FUNDBY                                                    NaN
# OTHER_MEDS                                                  NaN
# CUR_ILL                                                     NaN
# HISTORY                                                     NaN
# PRIOR_VAX                                                   NaN
# SPLTTYPE                                                    NaN
# FORM_VERS                                                     2
# TODAYS_DATE                                          01/01/2020
# BIRTH_DEFECT                                                NaN
# OFC_VISIT                                                     Y
# ER_ED_VISIT                                                 NaN
# ALLERGIES                                                   NaN
#
#                                                               5
# VAERS_ID                                                 855022
# RECVDATE                                             01/01/2020
# STATE                                                        FL
# AGE_YRS                                                      65
# CAGE_YR                                                      65
# CAGE_MO                                                     NaN
# SEX                                                           F
# RPT_DATE                                                    NaN
# SYMPTOM_TEXT  Expected redness/soreness roughly 24 hours aft...
# DIED                                                        NaN
# DATEDIED                                                    NaN
# L_THREAT                                                    NaN
# ER_VISIT                                                    NaN
# HOSPITAL                                                    NaN
# HOSPDAYS                                                    NaN
# X_STAY                                                      NaN
# DISABLE                                                     NaN
# RECOVD                                                        N
# VAX_DATE                                             12/29/2019
# ONSET_DATE                                           01/01/2020
# NUMDAYS                                                       3
# LAB_DATA                                                    NaN
# V_ADMINBY                                                   PHM
# V_FUNDBY                                                    NaN
# OTHER_MEDS    Metronidazole 0.75% cream to face BID Estradio...
# CUR_ILL                                                    None
# HISTORY                                       Stable osteopenia
# PRIOR_VAX                                                   NaN
# SPLTTYPE                                                    NaN
# FORM_VERS                                                     2
# TODAYS_DATE                                          01/01/2020
# BIRTH_DEFECT                                                NaN
# OFC_VISIT                                                   NaN
# ER_ED_VISIT                                                 NaN
# ALLERGIES     Anaphylaxis to peanuts, cashew, almond paste. ...

# %% [markdown]
# ## Merge the symptom labels
#
# Now let's merge all symptom labels in one `SYMPTOMS` column

# %% [markdown]
# ### First round, merge each row

# %%
def merge_symptoms(r):
    syms = []
    
    # check each symptom
    for i in [1,2,3,4,5]:
        _sym = r['SYMPTOM%s' % i]
        if pd.isna(_sym): continue
        
        # replace the blank
        _sym = _sym.replace(' ', '_')
        syms.append(_sym)
    
    return syms
    
df_sym['SYMPTOMS'] = df_sym.apply(merge_symptoms, axis=1)

df_sym.head()
# Out:
#    VAERS_ID           SYMPTOM1  SYMPTOMVERSION1                SYMPTOM2  \
# 0    855017         Arthralgia             22.1                  Chills
# 1    855018             Chills             22.1                 Fatigue
# 2    855018  Muscular weakness             22.1       Pain in extremity
# 3    855019               Pain             22.1                Pruritus
# 4    855020             Chills             22.1  Influenza like illness
#
#    SYMPTOMVERSION2             SYMPTOM3  SYMPTOMVERSION3           SYMPTOM4  \
# 0             22.1  Injection site pain             22.1            Pyrexia
# 1             22.1         Hypertension             22.1      Hypoaesthesia
# 2             22.1              Pyrexia             22.1             Tremor
# 3             22.1                 Rash             22.1                NaN
# 4             22.1              Myalgia             22.1  Pain in extremity
#
#    SYMPTOMVERSION4                          SYMPTOM5  SYMPTOMVERSION5  \
# 0             22.1                               NaN              NaN
# 1             22.1  Injected limb mobility decreased             22.1
# 2             22.1                           Vertigo             22.1
# 3              NaN                               NaN              NaN
# 4             22.1                           Pyrexia             22.1
#
#                                             SYMPTOMS
# 0  [Arthralgia, Chills, Injection_site_pain, Pyre...
# 1  [Chills, Fatigue, Hypertension, Hypoaesthesia,...
# 2  [Muscular_weakness, Pain_in_extremity, Pyrexia...
# 3                             [Pain, Pruritus, Rash]
# 4  [Chills, Influenza_like_illness, Myalgia, Pain...

# %% [markdown]
# ### Second round, groupby VAERS_ID
#
# Due to the duplicated VAERS_ID in the data, we need to combine them and remove the duplicated.

# %%
# group the syms and reduce the duplicated ones
df_sym_grouped = df_sym.groupby(['VAERS_ID'])['SYMPTOMS'].apply(
    lambda g: list(set(list(itertools.chain.from_iterable(g.values))))
)

# convert the series to a dataframe
df_sym_grouped = df_sym_grouped.to_frame()

# set the index
df_sym_grouped.reset_index(inplace=True)

# get the number of syms
df_sym_grouped['NUM_SYMS'] = df_sym_grouped['SYMPTOMS'].apply(lambda v: len(v))

# done, now for each VAERS_ID, we have a list of symptoms
df_sym_grouped.head()
# Out:
#    VAERS_ID                                           SYMPTOMS  NUM_SYMS
# 0    855017  [Chills, Arthralgia, Pyrexia, Injection_site_p...         4
# 1    855018  [Chills, Fatigue, Hypoaesthesia, Muscular_weak...        10
# 2    855019                             [Pruritus, Pain, Rash]         3
# 3    855020  [Chills, Influenza_like_illness, Pyrexia, Myal...         5
# 4    855021          [Chills, Dizziness, Palpitations, Nausea]         4

# %% [markdown]
# ## Merge the dataset
#
# Now let's make the dataset for downstream tasks

# %%
# merge the report text and vaccination info
# we don't need all of the columns in each dataframe
df = df_rpt[['VAERS_ID', 'AGE_YRS', 'SEX', 'VAX_DATE', 'SYMPTOM_TEXT', 'ALLERGIES']].merge(
    df_vax[['VAERS_ID', 'VAX_TYPE', 'VAX_MANU']].drop_duplicates(subset='VAERS_ID'),
    on='VAERS_ID',
    how='left'
)

# merge the first symptoms
df = df.merge(
    df_sym_grouped[['VAERS_ID', 'SYMPTOMS', 'NUM_SYMS']].drop_duplicates(subset='VAERS_ID'),
    on='VAERS_ID',
    how='left'
)

# we only use the COVID19 vaccination data
df = df[df['VAX_TYPE']=='COVID19']

# change the default datetime format for eaiser query
df['VAX_DATE'] = pd.to_datetime(df['VAX_DATE'], format='%m/%d/%Y')

# make sure the format is string for this two
df['SYMPTOM_TEXT'] = df['SYMPTOM_TEXT'].astype(str)

# calcuate the text length for the symptoms
df['TEXT_LEN'] = df['SYMPTOM_TEXT'].apply(lambda r: len(r))

# let's see how our dataframe looks like
print('* df size:', df['VAERS_ID'].count())
df.head()
# Out:
# * df size: 157099
#        VAERS_ID  AGE_YRS SEX   VAX_DATE  \
# 35000    902418     56.0   F 2020-12-15
# 35007    902440     35.0   F 2020-12-15
# 35008    902446     55.0   F 2020-12-15
# 35017    902464     42.0   M 2020-12-15
# 35018    902465     60.0   F 2020-12-15
#
#                                             SYMPTOM_TEXT  \
# 35000  Patient experienced mild numbness traveling fr...
# 35007                                       C/O Headache
# 35008  felt warm, hot and face and ears were red and ...
# 35017  within 15 minutes progressive light-headedness...
# 35018  Pt felt wave come over body @ 1218 starting in...
#
#                                              ALLERGIES VAX_TYPE  \
# 35000                                             none  COVID19
# 35007                                              NaN  COVID19
# 35008  Contrast Dye IV contrast, shellfish, strawberry  COVID19
# 35017                                             none  COVID19
# 35018                                           Biaxin  COVID19
#
#               VAX_MANU                                           SYMPTOMS  \
# 35000  PFIZER\BIONTECH      [Hypoaesthesia, Injection_site_hypoaesthesia]
# 35007  PFIZER\BIONTECH                                         [Headache]
# 35008  PFIZER\BIONTECH                  [Feeling_hot, Flushing, Erythema]
# 35017  PFIZER\BIONTECH  [Hyperhidrosis, Dizziness, Laboratory_test_nor...
# 35018  PFIZER\BIONTECH  [Dysgeusia, Sensory_disturbance, Parosmia, Tre...
#
#        NUM_SYMS  TEXT_LEN
# 35000       2.0       110
# 35007       1.0        12
# 35008       3.0        54
# 35017       5.0       124
# 35018       7.0       707

# %% [markdown]
# # Make sample and large dataset

# %%
# first, we only use the data in 2021
dft = df[df['VAX_DATE']>='2021-03-01']
print('* dft size:', dft['VAERS_ID'].count())

# then, we remove those records that are too short 
dft = dft[dft['TEXT_LEN']>80]
print('* dft size:', dft['VAERS_ID'].count())

# reset the index for spliting
dft.reset_index(inplace=True)

# then drop those not used columns
dft.drop(columns=['TEXT_LEN', 'VAX_TYPE', 'index'], inplace=True)

# then drop Nan
dft.dropna(inplace=True)
print('* final dft size:', dft['VAERS_ID'].count())

dft.head()
# Out:
# * dft size: 31631
# * dft size: 25140
# * final dft size: 17097
#    VAERS_ID  AGE_YRS SEX   VAX_DATE  \
# 0   1057076     68.0   F 2021-03-16
# 2   1062518     31.0   M 2021-03-01
# 3   1062652     63.0   F 2021-03-01
# 4   1062673     43.0   M 2021-03-01
# 5   1062721     36.0   F 2021-03-01
#
#                                         SYMPTOM_TEXT  \
# 0  I had the expected 24-48 hours of injection si...
# 2  Feeling dizzy and pale, felt weak  vital signs...
# 3  63 year old complained of headache and sweatin...
# 4  Pt received their second dose of the vaccine i...
# 5  Injection site it red and blotchy.  Area is cu...
#
#                                            ALLERGIES         VAX_MANU  \
# 0                               Sulfa, PCN, Dilantin          MODERNA
# 2                                         none known          MODERNA
# 3                                         Penicillin          MODERNA
# 4   hx of vasal vagal response with shots in general  PFIZER\BIONTECH
# 5  gluten dairy Setraline Amatriplatline Zoloft C...  PFIZER\BIONTECH
#
#                                             SYMPTOMS  NUM_SYMS
# 0  [Injection_site_pruritus, Injection_site_swell...       3.0
# 2                      [Dizziness, Pallor, Asthenia]       3.0
# 3                          [Headache, Hyperhidrosis]       2.0
# 4                   [Dizziness, Hypotension, Pallor]       3.0
# 5            [Rash_macular, Injection_site_erythema]       2.0

# %% [markdown]
# # TOP N
#
# Let's check what are the top N symptoms

# %%
# Get all symptoms
sym_lists = dft.SYMPTOMS.values.tolist()

# use a dictionary as counter
counter = {}
for sym_list in sym_lists:
    for sym in sym_list:
        if sym not in counter: counter[sym] = 0
        counter[sym] += 1

# convert the counter as a dataframe for better display
df_sym_counter = pd.DataFrame(counter.items(), columns=['SYMPTOM', 'COUNT'])
df_sym_counter.sort_values(by=['COUNT'], ascending=False).head(10)
# Out:
#                SYMPTOM  COUNT
# 6             Headache   5555
# 23             Pyrexia   4501
# 45              Chills   4498
# 53             Fatigue   3873
# 54                Pain   3837
# 24              Nausea   3178
# 3            Dizziness   3083
# 84   Pain_in_extremity   1873
# 19            Dyspnoea   1586
# 262            Myalgia   1541

# %% [markdown]
# # Output top 10

# %%
# we could select the top 10 symptoms according to our dataset
aes = df_sym_counter.sort_values(by=['COUNT'], ascending=False).head(10)['SYMPTOM'].tolist()
print('* top 10 symptoms:', aes)
# Out:
# * top 10 symptoms: ['Headache', 'Pyrexia', 'Chills', 'Fatigue', 'Pain', 'Nausea', 'Dizziness', 'Pain_in_extremity', 'Dyspnoea', 'Myalgia']

# %%
# sample 500 records
dft_allsample = dft.sample(n=500)

# get those are not used for sample
dft_notsample = dft[~dft.index.isin(dft_allsample.index)]

print('* dft_allsample:', dft_allsample.shape)
print('* dft_notsample:', dft_notsample.shape)
# Out:
# * dft_allsample: (500, 9)
# * dft_notsample: (16597, 9)

# %%
dft_allsample.to_csv('m_sample.csv', index=False)
dft_notsample.to_csv('m_large.csv', index=False)

print('* generated m_sample.csv and m_large.csv')
# Out:
# * generated m_sample.csv and m_large.csv
